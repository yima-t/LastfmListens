# %% [markdown]
# First we write a function to collect Data from the last.fm Api endpoint.
# The endpoint being used is the GetRecentTracks endpoint to get all the tracks scrobbled

# %%
import requests as rq

API_KEY = 'insertkey'
USER_AGENT = 'Ewaoluwa'
user='ewaoluwa'

def lastfm_get(payload):
    headers= {'user-agent': USER_AGENT}
    url = 'https://ws.audioscrobbler.com/2.0/'

    payload['limit'] = 200
    payload['user']= user
    payload['api_key'] = API_KEY
    payload['format'] = 'json'


    response = rq.get(url,headers=headers, params=payload)
    return response

import requests_cache
requests_cache.install_cache()

import time
from IPython.core.display import clear_output

responses = []

page = 1
total_pages = 99999 # this is just a dummy number so the loop starts

while page <= total_pages:
    payload = {
        'method': 'user.getrecenttracks',
        'limit': 200,
        'user': user,
        'page': page
    }

    # print some output so we can see the status
    print("Requesting page {}/{}".format(page, total_pages))
    # clear the output to make things neater
    clear_output(wait = True)

    # make the API call
    response = lastfm_get(payload)

    # if we get an error, print the response and halt the loop
    if response.status_code != 200:
        print(response.text)
        break

    # extract pagination info
    page = int(response.json()['recenttracks']['@attr']['page'])
    total_pages = int(response.json()['recenttracks']['@attr']['totalPages'])

    # append response
    responses.append(response)

    # if it's not a cached result, sleep
    if not getattr(response, 'from_cache', False):
        time.sleep(0.25)

    # increment the page number
    page += 1

import pandas as pd

r0 = responses[0]
r0_json = r0.json()
r0_tracks = r0_json['recenttracks']['track']
r0_df = pd.DataFrame(r0_tracks)
r0_df.head()

frames = [pd.DataFrame(r.json()['recenttracks']['track']) for r in responses]
tracks = pd.concat(frames)
tracks.head()

print(tracks.columns)

tracks.head()
# Out:
# Index(['artist', 'streamable', 'image', 'mbid', 'album', 'name', 'url',
#        'date'],
#       dtype='object')
#                                               artist streamable  \
# 0  {'mbid': 'e520459c-dff4-491d-a6e4-c97be35e0044...          0
# 1  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...          0
# 2  {'mbid': 'a6c6897a-7415-4f8d-b5a5-3a5e05f3be67...          0
# 3  {'mbid': '01695167-968d-4afc-9f94-06c33ebabe16...          0
# 4  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...          0
#
#                                                image  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#                                    mbid  \
# 0  dddbb3b9-7ed5-362c-983f-0d28b047dbf0
# 1  e28c3490-8d2a-487a-8039-5540ed58d652
# 2  11161115-4dd0-418b-b0b8-5a5c6571b09f
# 3
# 4  5d0df10b-a90b-4515-a876-1b5abf378cba
#
#                                                album  \
# 0  {'mbid': '16f3fcf2-4511-4c8c-93bb-b4c8910aa9db...
# 1  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
# 2  {'mbid': '136434d5-9ddf-4c62-8dcc-021ead11fe0c...
# 3                   {'mbid': '', '#text': 'Mr Blue'}
# 4  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
#
#                        name  \
# 0                  Novacane
# 1  Don't Get Lost in Heaven
# 2                     Goner
# 3       Mr Blue (Radio Mix)
# 4                 El Mañana
#
#                                                  url  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...
# 2  https://www.last.fm/music/twenty+one+pilots/_/...
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...
#
#                                                 date
# 0  {'uts': '1699143073', '#text': '05 Nov 2023, 0...
# 1  {'uts': '1699142942', '#text': '05 Nov 2023, 0...
# 2  {'uts': '1699142704', '#text': '05 Nov 2023, 0...
# 3  {'uts': '1699142521', '#text': '05 Nov 2023, 0...
# 4  {'uts': '1699142291', '#text': '04 Nov 2023, 2...

# %% [markdown]
# Cleaning the data by dropping columns that are not needed

# %%
tracks=tracks.drop(['mbid','streamable'], axis=1)

# %% [markdown]
# Creating a new dataframe that contains only the distinct tracks so we can use the track name to get the top tags from each track using another endpoint

# %%
tracksdistinct= tracks.drop_duplicates(subset=["url"])
tracksdistinct.describe()
# Out:
#                                                    artist  \
# count                                                6028
# unique                                               2269
# top     {'mbid': '164f0d73-1234-4e2c-8743-d77bf2191051...
# freq                                                  171
#
#                                                     image  \
# count                                                6028
# unique                                               2676
# top     [{'size': 'small', '#text': 'https://lastfm.fr...
# freq                                                  675
#
#                             album   name  \
# count                        6028   6028
# unique                       3069   5698
# top     {'mbid': '', '#text': ''}  Intro
# freq                          510      6
#
#                                                      url  \
# count                                               6028
# unique                                              6028
# top     https://www.last.fm/music/Frank+Ocean/_/Novacane
# freq                                                   1
#
#                                                      date
# count                                                6028
# unique                                               5951
# top     {'uts': '1623907212', '#text': '17 Jun 2021, 0...
# freq                                                   23

# %%
tracksdistinct=tracksdistinct.rename(columns={'name':'track'})
tracksdistinct.head()
# Out:
#               artist                                              image  \
# 0        Frank Ocean  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  twenty one pilots  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3    Catherine Feeny  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#         album                     track  \
# 0    Novacane                  Novacane
# 1  Demon Days  Don't Get Lost in Heaven
# 2  Blurryface                     Goner
# 3     Mr Blue       Mr Blue (Radio Mix)
# 4  Demon Days                 El Mañana
#
#                                                  url                date
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane  05 Nov 2023, 00:11
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...  05 Nov 2023, 00:09
# 2  https://www.last.fm/music/twenty+one+pilots/_/...  05 Nov 2023, 00:05
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...  05 Nov 2023, 00:02
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...  04 Nov 2023, 23:58

# %%
tracksdistinct['artist'] = tracksdistinct['artist'].apply(lambda x: x['#text'])
tracksdistinct['album'] = tracksdistinct['album'].apply(lambda x: x['#text'])
tracksdistinct['date'] = tracksdistinct['date'].apply(lambda x: x['#text'])
tracksdistinct.head()
# Out:
#               artist                                              image  \
# 0        Frank Ocean  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  twenty one pilots  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3    Catherine Feeny  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#         album                     track  \
# 0    Novacane                  Novacane
# 1  Demon Days  Don't Get Lost in Heaven
# 2  Blurryface                     Goner
# 3     Mr Blue       Mr Blue (Radio Mix)
# 4  Demon Days                 El Mañana
#
#                                                  url                date
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane  05 Nov 2023, 00:11
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...  05 Nov 2023, 00:09
# 2  https://www.last.fm/music/twenty+one+pilots/_/...  05 Nov 2023, 00:05
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...  05 Nov 2023, 00:02
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...  04 Nov 2023, 23:58

# %%
def lookup_tags(artist,track):
    responser = lastfm_get({
        'method': 'track.getTopTags',
        'artist':  artist,
        'track': track
    })

    # if there's an error, just return nothing
    if responser.status_code != 200:
        return None

    # extract the top three tags and turn them into a string
    tags = [t['name'] for t in responser.json()['toptags']['tag'][:3]]
    tags_str = ', '.join(tags)

    # rate limiting
    if not getattr(responser, 'from_cache', False):
        time.sleep(0.25)
    return tags_str

from tqdm import tqdm
tqdm.pandas()

tracksdistinct['tags'] = tracksdistinct[['artist', 'track']].progress_apply(lambda row: lookup_tags(row['artist'], row['track']), axis=1)

tracksdistinct.head()
# Out:
# 100%|██████████| 6028/6028 [2:00:49<00:00,  1.20s/it]
#               artist                                              image  \
# 0        Frank Ocean  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  twenty one pilots  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3    Catherine Feeny  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#         album                     track  \
# 0    Novacane                  Novacane
# 1  Demon Days  Don't Get Lost in Heaven
# 2  Blurryface                     Goner
# 3     Mr Blue       Mr Blue (Radio Mix)
# 4  Demon Days                 El Mañana
#
#                                                  url                date  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane  05 Nov 2023, 00:11
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...  05 Nov 2023, 00:09
# 2  https://www.last.fm/music/twenty+one+pilots/_/...  05 Nov 2023, 00:05
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...  05 Nov 2023, 00:02
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...  04 Nov 2023, 23:58
#
#                                          tags
# 0                           rnb, r&b, ofwgkta
# 1             alternative, trip-hop, gorillaz
# 2  indie pop, alternative hip hop, electropop
# 3
# 4           alternative, electronic, trip-hop

# %%
tracksdistinct.dtypes
# Out:
# artist    object
# image     object
# album     object
# track     object
# url       object
# date      object
# tags      object
# dtype: object

# %%
#joining the dataframes

full_tracks=pd.merge(tracks, tracksdistinct, on='url', how='left')
print(full_tracks.head())
# Out:
#                                             artist_x  \
# 0  {'mbid': 'e520459c-dff4-491d-a6e4-c97be35e0044...
# 1  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...
# 2  {'mbid': 'a6c6897a-7415-4f8d-b5a5-3a5e05f3be67...
# 3  {'mbid': '01695167-968d-4afc-9f94-06c33ebabe16...
# 4  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...
#
#                                              image_x  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#                                              album_x  \
# 0  {'mbid': '16f3fcf2-4511-4c8c-93bb-b4c8910aa9db...
# 1  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
# 2  {'mbid': '136434d5-9ddf-4c62-8dcc-021ead11fe0c...
# 3                   {'mbid': '', '#text': 'Mr Blue'}
# 4  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
#
#                        name  \
# 0                  Novacane
# 1  Don't Get Lost in Heaven
# 2                     Goner
# 3       Mr Blue (Radio Mix)
# 4                 El Mañana
#
#                                                  url  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...
# 2  https://www.last.fm/music/twenty+one+pilots/_/...
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...
#
#                                               date_x           artist_y  \
# 0  {'uts': '1699143073', '#text': '05 Nov 2023, 0...        Frank Ocean
# 1  {'uts': '1699142942', '#text': '05 Nov 2023, 0...           Gorillaz
# 2  {'uts': '1699142704', '#text': '05 Nov 2023, 0...  twenty one pilots
# 3  {'uts': '1699142521', '#text': '05 Nov 2023, 0...    Catherine Feeny
# 4  {'uts': '1699142291', '#text': '04 Nov 2023, 2...           Gorillaz
#
#                                              image_y     album_y  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...    Novacane
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...  Demon Days
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...  Blurryface
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...     Mr Blue
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...  Demon Days
#
#                       track              date_y  \
# 0                  Novacane  05 Nov 2023, 00:11
# 1  Don't Get Lost in Heaven  05 Nov 2023, 00:09
# 2                     Goner  05 Nov 2023, 00:05
# 3       Mr Blue (Radio Mix)  05 Nov 2023, 00:02
# 4                 El Mañana  04 Nov 2023, 23:58
#
#                                          tags
# 0                           rnb, r&b, ofwgkta
# 1             alternative, trip-hop, gorillaz
# 2  indie pop, alternative hip hop, electropop
# 3
# 4           alternative, electronic, trip-hop

# %%
full_tracks.head()
# Out:
#                                             artist_x  \
# 0  {'mbid': 'e520459c-dff4-491d-a6e4-c97be35e0044...
# 1  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...
# 2  {'mbid': 'a6c6897a-7415-4f8d-b5a5-3a5e05f3be67...
# 3  {'mbid': '01695167-968d-4afc-9f94-06c33ebabe16...
# 4  {'mbid': 'e21857d5-3256-4547-afb3-4b6ded592596...
#
#                                              image_x  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#                                              album_x  \
# 0  {'mbid': '16f3fcf2-4511-4c8c-93bb-b4c8910aa9db...
# 1  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
# 2  {'mbid': '136434d5-9ddf-4c62-8dcc-021ead11fe0c...
# 3                   {'mbid': '', '#text': 'Mr Blue'}
# 4  {'mbid': '0380808d-2211-4869-a287-cc94e0d18162...
#
#                        name  \
# 0                  Novacane
# 1  Don't Get Lost in Heaven
# 2                     Goner
# 3       Mr Blue (Radio Mix)
# 4                 El Mañana
#
#                                                  url  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...
# 2  https://www.last.fm/music/twenty+one+pilots/_/...
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...
#
#                                               date_x           artist_y  \
# 0  {'uts': '1699143073', '#text': '05 Nov 2023, 0...        Frank Ocean
# 1  {'uts': '1699142942', '#text': '05 Nov 2023, 0...           Gorillaz
# 2  {'uts': '1699142704', '#text': '05 Nov 2023, 0...  twenty one pilots
# 3  {'uts': '1699142521', '#text': '05 Nov 2023, 0...    Catherine Feeny
# 4  {'uts': '1699142291', '#text': '04 Nov 2023, 2...           Gorillaz
#
#                                              image_y     album_y  \
# 0  [{'size': 'small', '#text': 'https://lastfm.fr...    Novacane
# 1  [{'size': 'small', '#text': 'https://lastfm.fr...  Demon Days
# 2  [{'size': 'small', '#text': 'https://lastfm.fr...  Blurryface
# 3  [{'size': 'small', '#text': 'https://lastfm.fr...     Mr Blue
# 4  [{'size': 'small', '#text': 'https://lastfm.fr...  Demon Days
#
#                       track              date_y  \
# 0                  Novacane  05 Nov 2023, 00:11
# 1  Don't Get Lost in Heaven  05 Nov 2023, 00:09
# 2                     Goner  05 Nov 2023, 00:05
# 3       Mr Blue (Radio Mix)  05 Nov 2023, 00:02
# 4                 El Mañana  04 Nov 2023, 23:58
#
#                                          tags
# 0                           rnb, r&b, ofwgkta
# 1             alternative, trip-hop, gorillaz
# 2  indie pop, alternative hip hop, electropop
# 3
# 4           alternative, electronic, trip-hop

# %%
full_tracks=full_tracks.drop(['artist_x','album_x','name','date_y','image_x'],axis=1)
full_tracks['date_x'] = full_tracks['date_x'].apply(lambda x: x['#text'])
full_tracks.head()
# Out:
#                                                  url              date_x  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane  05 Nov 2023, 00:11
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G...  05 Nov 2023, 00:09
# 2  https://www.last.fm/music/twenty+one+pilots/_/...  05 Nov 2023, 00:05
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr...  05 Nov 2023, 00:02
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%...  04 Nov 2023, 23:58
#
#             artist_y                                            image_y  \
# 0        Frank Ocean  [{'size': 'small', '#text': 'https://lastfm.fr...
# 1           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
# 2  twenty one pilots  [{'size': 'small', '#text': 'https://lastfm.fr...
# 3    Catherine Feeny  [{'size': 'small', '#text': 'https://lastfm.fr...
# 4           Gorillaz  [{'size': 'small', '#text': 'https://lastfm.fr...
#
#       album_y                     track  \
# 0    Novacane                  Novacane
# 1  Demon Days  Don't Get Lost in Heaven
# 2  Blurryface                     Goner
# 3     Mr Blue       Mr Blue (Radio Mix)
# 4  Demon Days                 El Mañana
#
#                                          tags
# 0                           rnb, r&b, ofwgkta
# 1             alternative, trip-hop, gorillaz
# 2  indie pop, alternative hip hop, electropop
# 3
# 4           alternative, electronic, trip-hop

# %%
full_tracks=full_tracks.rename(columns={'artist_y':'artist', 'album_y':'album', 'date_x':'date', 'image_y':'image'})

# %%
full_tracks=full_tracks.astype(str)

# %%
print(full_tracks.dtypes)
# Out:
# url       object
# date      object
# artist    object
# image     object
# album     object
# track     object
# tags      object
# dtype: object

# %%
import datetime
full_tracks['date'] = full_tracks['date'].apply(lambda x: datetime.datetime.strptime(x, '%d %b %Y, %H:%M'))

# %%
print(full_tracks.dtypes)
# Out:
# url               object
# date      datetime64[ns]
# artist            object
# image             object
# album             object
# track             object
# tags              object
# dtype: object

# %%
import ast
def extract_medium_link(row):
    try:
        row_list = ast.literal_eval(row)  # Safely convert the string to a list
        for item in row_list:
            if item['size'] == 'medium':
                return item['#text']
    except (ValueError, SyntaxError):
        pass  # Handle the case where the data can't be parsed

    return None  # Return None if a medium-sized image is not found

full_tracks['image'] = full_tracks['image'].apply(extract_medium_link)
full_tracks.head()
# Out:
#                                                  url                date  \
# 0   https://www.last.fm/music/Frank+Ocean/_/Novacane 2023-11-05 00:11:00
# 1  https://www.last.fm/music/Gorillaz/_/Don%27t+G... 2023-11-05 00:09:00
# 2  https://www.last.fm/music/twenty+one+pilots/_/... 2023-11-05 00:05:00
# 3  https://www.last.fm/music/Catherine+Feeny/_/Mr... 2023-11-05 00:02:00
# 4  https://www.last.fm/music/Gorillaz/_/El+Ma%C3%... 2023-11-04 23:58:00
#
#               artist                                              image  \
# 0        Frank Ocean  https://lastfm.freetls.fastly.net/i/u/64s/7344...
# 1           Gorillaz  https://lastfm.freetls.fastly.net/i/u/64s/2714...
# 2  twenty one pilots  https://lastfm.freetls.fastly.net/i/u/64s/dc5b...
# 3    Catherine Feeny  https://lastfm.freetls.fastly.net/i/u/64s/81e0...
# 4           Gorillaz  https://lastfm.freetls.fastly.net/i/u/64s/2714...
#
#         album                     track  \
# 0    Novacane                  Novacane
# 1  Demon Days  Don't Get Lost in Heaven
# 2  Blurryface                     Goner
# 3     Mr Blue       Mr Blue (Radio Mix)
# 4  Demon Days                 El Mañana
#
#                                          tags
# 0                           rnb, r&b, ofwgkta
# 1             alternative, trip-hop, gorillaz
# 2  indie pop, alternative hip hop, electropop
# 3
# 4           alternative, electronic, trip-hop

# %%
full_tracks.to_csv('Ewaoluwa.csv', index=False)
